# %%
import pandas as pd

# %%
df = pd.read_csv('A_Z_medicines_dataset_of_India.csv')
df
# Out:
#             id                           name  price(₹)  Is_discontinued  \
# 0            1       Augmentin 625 Duo Tablet    223.42            False
# 1            2            Azithral 500 Tablet    132.36            False
# 2            3               Ascoril LS Syrup    118.00            False
# 3            4           Allegra 120mg Tablet    218.81            False
# 4            5                 Avil 25 Tablet     10.96            False
# ...        ...                            ...       ...              ...
# 253968  253969  Ziyapod 100mg Oral Suspension     62.30            False
# 253969  253970            Zemhart 30mg Tablet     54.00            False
# 253970  253971              Zivex 25mg Tablet     57.00            False
# 253971  253972        ZI Fast 500mg Injection    152.00            False
# 253972  253973      Zyvocol 1% Dusting Powder    110.00            False
#
#                             manufacturer_name       type  \
# ...

# %%
content = df[['name','short_composition1']].loc[df['name'].str.contains('Paracetamol', case=False)].iloc[0]['short_composition1']
content
# Out:
# 'Paracetamol (250mg)'

# %%
df[['name','price(₹)']].loc[df['short_composition1'] == content]
# Out:
#                                        name  price(₹)
# 2974                    Admol 250 DT Tablet     25.00
# 3782                     Arden 250mg Tablet     20.57
# 4224              ANAMOL 250 MG SUPPOSITORY     41.00
# 5433                       A 250 Suspension     28.50
# 8521            Asmol 250mg Oral Suspension     40.00
# ...                                     ...       ...
# 252222        Zadumol 250mg Oral Suspension     49.00
# 252270  Zenimol Forte 250mg Oral Suspension     28.00
# 252824         Zidfev 250mg Oral Suspension     36.00
# 253139          Zytamol 250 Oral Suspension     39.65
# 253697        Zoxepar 250mg Oral Suspension     40.00
#
# [205 rows x 2 columns]
